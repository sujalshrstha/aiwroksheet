# %% [markdown]
# <a href="https://colab.research.google.com/github/sujalshrstha/aiwroksheet/blob/main/2431235_sujalshrestha_Regression12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_set = pd.read_csv("/content/drive/MyDrive/Assesment Ai/better-life-index-2024.csv")
data_set.head(15)
# Out:
#        Country  GDP per capita (USD)    Dwellings without basic facilities  \
# 0    Australia                 66589                                   NaN
# 1      Austria                 59225                                   0.8
# 2      Belgium                 55536                                   0.7
# 3       Canada                 54866                                   0.2
# 4        Chile                 16616                                   9.4
# 5     Colombia                  7327                                  12.3
# 6   Costa Rica                 18031                                   2.3
# 7      Czechia                 29801                                   0.5
# 8      Denmark                 68898                                   0.5
# 9      Estonia                 31855                                   5.7
# 10     Finland                 55127                                   0.4
# 11      France                 47359                                   0.5
# 12     Germany                 54291                                   0.1
# 13      Greece                 23966                                   0.4
# 14     Hungary                 23319                                   3.5
#
#       Housing expenditure    Rooms per person  \
# 0                    19.4                 NaN
# 1                    20.8                 1.6
# 2                    20.0                 2.1
# 3                    22.9                 2.6
# 4                    18.4                 1.9
# 5                     NaN                 1.0
# 6                    17.0                 1.2
# 7                    23.4                 1.5
# 8                    23.3                 1.9
# 9                    17.0                 1.7
# 10                   23.1                 1.9
# 11                   20.7                 1.8
# 12                   20.0                 1.8
# 13                   21.8                 1.2
# 14                   19.9                 1.4
#
#       Household net adjusted disposable income    Household net wealth  \
# 0                                      37433.0                528768.0
# 1                                      37001.0                309637.0
# 2                                      34884.0                447607.0
# 3                                      34421.0                478240.0
# 4                                          NaN                135787.0
# 5                                          NaN                     NaN
# 6                                      16517.0                     NaN
# 7                                      26664.0                     NaN
# 8                                      33774.0                149864.0
# 9                                      23784.0                188627.0
# 10                                     33471.0                230032.0
# 11                                     34375.0                298639.0
# 12                                     38971.0                304317.0
# 13                                     20791.0                148323.0
# 14                                     21026.0                150296.0
#
#       Labour market insecurity    Employment rate  \
# 0                          3.1                 73
# 1                          2.3                 72
# 2                          2.4                 65
# 3                          3.8                 70
# 4                          7.0                 56
# 5                          NaN                 58
# 6                          NaN                 55
# 7                          2.3                 74
# 8                          4.5                 74
# 9                          5.4                 74
# 10                         2.2                 72
# 11                         3.1                 65
# 12                         1.4                 77
# 13                        21.7                 56
# 14                         3.8                 70
#
#       Long-term unemployment rate  ...    Water quality  \
# 0                             1.0  ...               92
# 1                             1.3  ...               92
# 2                             2.3  ...               79
# 3                             0.5  ...               90
# 4                             NaN  ...               62
# 5                             1.1  ...               82
# 6                             1.5  ...               87
# 7                             0.6  ...               89
# 8                             0.9  ...               93
# 9                             1.2  ...               86
# 10                            1.2  ...               97
# 11                            2.9  ...               78
# 12                            1.2  ...               91
# 13                           10.8  ...               67
# 14                            1.2  ...               81
#
#       Stakeholder engagement for developing regulations    Voter turnout  \
# 0                                                 2.7                 92
# 1                                                 1.3                 76
# 2                                                 2.0                 88
# 3                                                 2.9                 68
# 4                                                 1.3                 47
# 5                                                 1.4                 53
# 6                                                 1.8                 66
# 7                                                 1.6                 62
# 8                                                 2.0                 85
# 9                                                 2.7                 64
# 10                                                2.2                 69
# 11                                                2.1                 75
# 12                                                1.8                 76
# 13                                                1.8                 58
# 14                                                1.2                 70
#
#       Life expectancy    Self-reported health  \
# 0                83.0                      85
# 1                82.0                      71
# 2                82.1                      74
# 3                82.1                      89
# 4                80.6                      60
# 5                76.7                      80
# 6                80.5                      73
# 7                79.3                      62
# 8                81.5                      70
# 9                78.8                      57
# 10               82.1                      68
# 11               82.9                      67
# 12               81.4                      66
# 13               81.7                      79
# 14               76.4                      58
#
#       Feeling safe walking alone at night    Homicide rate  \
# 0                                      67              0.9
# 1                                      86              0.5
# 2                                      56              1.1
# 3                                      78              1.2
# 4                                      41              2.4
# 5                                      50             23.1
# 6                                      47             10.0
# 7                                      77              0.7
# 8                                      85              0.5
# 9                                      79              1.9
# 10                                     88              1.2
# 11                                     74              0.4
# 12                                     76              0.4
# 13                                     69              1.0
# 14                                     74              0.9
#
#       Employees working very long hours  \
# 0                                  12.5
# 1                                   5.3
# 2                                   4.3
# 3                                   3.3
# 4                                   7.7
# 5                                  23.7
# 6                                  22.0
# 7                                   4.5
# 8                                   1.1
# 9                                   2.2
# 10                                  3.6
# 11                                  7.7
# 12                                  3.9
# 13                                  4.5
# 14                                  1.5
#
#       Time devoted to leisure and personal care    Life satisfaction
# 0                                         14.36                  7.1
# 1                                         14.51                  7.2
# 2                                         15.52                  6.8
# 3                                         14.57                  7.0
# 4                                           NaN                  6.2
# 5                                           NaN                  5.7
# 6                                           NaN                  6.3
# 7                                           NaN                  6.9
# 8                                           NaN                  7.5
# 9                                         14.98                  6.5
# 10                                        15.17                  7.9
# 11                                        16.20                  6.7
# 12                                        15.62                  7.3
# 13                                        15.03                  5.8
# 14                                        15.08                  6.0
#
# [15 rows x 26 columns]

# %%
data_set
# Out:
#             Country  GDP per capita (USD)  \
# 0         Australia                 66589
# 1           Austria                 59225
# 2           Belgium                 55536
# 3            Canada                 54866
# 4             Chile                 16616
# 5          Colombia                  7327
# 6        Costa Rica                 18031
# 7           Czechia                 29801
# 8           Denmark                 68898
# 9           Estonia                 31855
# 10          Finland                 55127
# 11           France                 47359
# 12          Germany                 54291
# 13           Greece                 23966
# 14          Hungary                 23319
# 15          Iceland                 84594
# 16          Ireland                106059
# 17           Israel                 53372
# 18            Italy                 39580
# 19            Japan                 33138
# 20            Korea                 34165
# 21           Latvia                 24194
# 22        Lithuania                 28407
# 23       Luxembourg                131384
# 24           Mexico                 15249
# 25      Netherlands                 63750
# 26      New Zealand                 48531
# 27           Norway                 94660
# 28           Poland                 23014
# 29         Portugal                 28969
# 30  Slovak Republic                 25935
# 31         Slovenia                 34026
# 32            Spain                 34045
# 33           Sweden                 58529
# 34      Switzerland                105669
# 35          Türkiye                 12765
# 36   United Kingdom                 51075
# 37    United States                 85373
#
#       Dwellings without basic facilities    Housing expenditure  \
# 0                                    NaN                   19.4
# 1                                    0.8                   20.8
# 2                                    0.7                   20.0
# 3                                    0.2                   22.9
# 4                                    9.4                   18.4
# 5                                   12.3                    NaN
# 6                                    2.3                   17.0
# 7                                    0.5                   23.4
# 8                                    0.5                   23.3
# 9                                    5.7                   17.0
# 10                                   0.4                   23.1
# 11                                   0.5                   20.7
# 12                                   0.1                   20.0
# 13                                   0.4                   21.8
# 14                                   3.5                   19.9
# 15                                   0.0                    NaN
# 16                                   0.2                   20.6
# 17                                   NaN                    NaN
# 18                                   0.6                   22.5
# 19                                   6.4                   21.8
# 20                                   2.5                   14.7
# 21                                  11.2                   20.8
# 22                                  11.8                   18.4
# 23                                   0.1                   20.7
# 24                                  25.9                   17.8
# 25                                   0.1                   19.6
# 26                                   NaN                   25.0
# 27                                   0.0                   17.7
# 28                                   2.3                   21.2
# 29                                   0.9                   19.6
# 30                                   1.5                   27.4
# 31                                   0.2                   18.2
# 32                                   0.3                   21.7
# 33                                   0.0                   20.1
# 34                                   0.0                   21.4
# 35                                   4.9                   18.9
# 36                                   0.5                   23.2
# 37                                   0.1                   18.3
#
#       Rooms per person    Household net adjusted disposable income  \
# 0                  NaN                                     37433.0
# 1                  1.6                                     37001.0
# 2                  2.1                                     34884.0
# 3                  2.6                                     34421.0
# 4                  1.9                                         NaN
# 5                  1.0                                         NaN
# 6                  1.2                                     16517.0
# 7                  1.5                                     26664.0
# 8                  1.9                                     33774.0
# 9                  1.7                                     23784.0
# 10                 1.9                                     33471.0
# 11                 1.8                                     34375.0
# 12                 1.8                                     38971.0
# 13                 1.2                                     20791.0
# 14                 1.4                                     21026.0
# 15                 1.6                                         NaN
# 16                 2.1                                     29488.0
# 17                 1.2                                         NaN
# 18                 1.4                                     29431.0
# 19                 1.9                                     28872.0
# 20                 1.5                                     24590.0
# 21                 1.2                                     19783.0
# 22                 1.5                                     26976.0
# 23                 2.0                                     44773.0
# 24                 1.1                                     16269.0
# 25                 2.0                                     34984.0
# 26                 2.4                                     39024.0
# 27                 2.1                                     39144.0
# 28                 1.1                                     23675.0
# 29                 1.7                                     24877.0
# 30                 1.1                                     21149.0
# 31                 1.6                                     25250.0
# 32                 1.9                                     27155.0
# 33                 1.7                                     33730.0
# 34                 1.9                                     39697.0
# 35                 1.0                                         NaN
# 36                 2.0                                     33049.0
# 37                 2.4                                     51147.0
#
#       Household net wealth    Labour market insecurity    Employment rate  \
# 0                 528768.0                         3.1                 73
# 1                 309637.0                         2.3                 72
# 2                 447607.0                         2.4                 65
# 3                 478240.0                         3.8                 70
# 4                 135787.0                         7.0                 56
# 5                      NaN                         NaN                 58
# 6                      NaN                         NaN                 55
# 7                      NaN                         2.3                 74
# 8                 149864.0                         4.5                 74
# 9                 188627.0                         5.4                 74
# 10                230032.0                         2.2                 72
# 11                298639.0                         3.1                 65
# 12                304317.0                         1.4                 77
# 13                148323.0                        21.7                 56
# 14                150296.0                         3.8                 70
# 15                     NaN                         1.0                 78
# 16                370341.0                         2.6                 68
# 17                     NaN                         4.6                 67
# 18                295020.0                         8.6                 58
# 19                294735.0                         2.7                 77
# 20                362340.0                         2.9                 66
# 21                 79245.0                         6.3                 72
# 22                182039.0                         NaN                 72
# 23                941162.0                         2.2                 67
# 24                     NaN                         4.0                 59
# 25                248599.0                         2.5                 78
# 26                514162.0                         4.5                 77
# 27                268358.0                         2.8                 75
# 28                233221.0                         5.0                 69
# 29                255303.0                         8.1                 69
# 30                171425.0                         8.8                 68
# 31                233286.0                         5.9                 71
# 32                366534.0                        15.8                 62
# 33                     NaN                         4.4                 75
# 34                     NaN                         NaN                 80
# 35                     NaN                        13.0                 48
# 36                524422.0                         3.3                 75
# 37                684500.0                         4.2                 67
#
#       Long-term unemployment rate  ...    Water quality  \
# 0                             1.0  ...               92
# 1                             1.3  ...               92
# 2                             2.3  ...               79
# 3                             0.5  ...               90
# 4                             NaN  ...               62
# 5                             1.1  ...               82
# 6                             1.5  ...               87
# 7                             0.6  ...               89
# 8                             0.9  ...               93
# 9                             1.2  ...               86
# 10                            1.2  ...               97
# 11                            2.9  ...               78
# 12                            1.2  ...               91
# 13                           10.8  ...               67
# 14                            1.2  ...               81
# 15                            0.7  ...               97
# 16                            1.2  ...               80
# 17                            0.2  ...               77
# 18                            4.8  ...               77
# 19                            0.8  ...               87
# 20                            0.0  ...               82
# 21                            2.2  ...               83
# 22                            2.5  ...               83
# 23                            1.7  ...               85
# 24                            0.1  ...               75
# 25                            0.9  ...               91
# 26                            0.4  ...               85
# 27                            0.9  ...               98
# 28                            0.6  ...               82
# 29                            2.3  ...               89
# 30                            3.0  ...               81
# 31                            1.9  ...               93
# 32                            5.0  ...               76
# 33                            1.0  ...               97
# 34                            1.7  ...               96
# 35                            3.3  ...               62
# 36                            0.9  ...               82
# 37                            0.5  ...               88
#
#       Stakeholder engagement for developing regulations    Voter turnout  \
# 0                                                 2.7                 92
# 1                                                 1.3                 76
# 2                                                 2.0                 88
# 3                                                 2.9                 68
# 4                                                 1.3                 47
# 5                                                 1.4                 53
# 6                                                 1.8                 66
# 7                                                 1.6                 62
# 8                                                 2.0                 85
# 9                                                 2.7                 64
# 10                                                2.2                 69
# 11                                                2.1                 75
# 12                                                1.8                 76
# 13                                                1.8                 58
# 14                                                1.2                 70
# 15                                                2.1                 81
# 16                                                1.3                 63
# 17                                                2.5                 67
# 18                                                2.5                 73
# 19                                                1.4                 53
# 20                                                2.9                 77
# 21                                                2.2                 55
# 22                                                2.4                 57
# 23                                                1.7                 90
# 24                                                3.2                 63
# 25                                                2.6                 79
# 26                                                2.5                 82
# 27                                                2.2                 78
# 28                                                2.6                 68
# 29                                                1.5                 49
# 30                                                3.0                 66
# 31                                                2.5                 53
# 32                                                1.8                 72
# 33                                                2.0                 87
# 34                                                2.3                 45
# 35                                                1.5                 86
# 36                                                3.1                 68
# 37                                                3.1                 65
#
#       Life expectancy    Self-reported health  \
# 0                83.0                      85
# 1                82.0                      71
# 2                82.1                      74
# 3                82.1                      89
# 4                80.6                      60
# 5                76.7                      80
# 6                80.5                      73
# 7                79.3                      62
# 8                81.5                      70
# 9                78.8                      57
# 10               82.1                      68
# 11               82.9                      67
# 12               81.4                      66
# 13               81.7                      79
# 14               76.4                      58
# 15               83.2                      77
# 16               82.8                      84
# 17               82.9                      74
# 18               83.6                      73
# 19               84.4                      37
# 20               83.3                      34
# 21               75.5                      47
# 22               76.4                      46
# 23               82.7                      72
# 24               75.1                      66
# 25               82.2                      75
# 26               82.1                      86
# 27               83.0                      75
# 28               78.0                      60
# 29               81.8                      50
# 30               77.8                      65
# 31               81.6                      67
# 32               83.9                      75
# 33               83.2                      76
# 34               84.0                      81
# 35               78.6                      67
# 36               81.3                      73
# 37               78.9                      88
#
#       Feeling safe walking alone at night    Homicide rate  \
# 0                                      67              0.9
# 1                                      86              0.5
# 2                                      56              1.1
# 3                                      78              1.2
# 4                                      41              2.4
# 5                                      50             23.1
# 6                                      47             10.0
# 7                                      77              0.7
# 8                                      85              0.5
# 9                                      79              1.9
# 10                                     88              1.2
# 11                                     74              0.4
# 12                                     76              0.4
# 13                                     69              1.0
# 14                                     74              0.9
# 15                                     85              0.3
# 16                                     76              0.5
# 17                                     80              1.5
# 18                                     73              0.5
# 19                                     77              0.2
# 20                                     82              0.8
# 21                                     72              3.7
# 22                                     62              2.5
# 23                                     87              0.2
# 24                                     42             26.8
# 25                                     83              0.6
# 26                                     66              1.3
# 27                                     93              0.6
# 28                                     71              0.5
# 29                                     83              0.7
# 30                                     76              0.8
# 31                                     91              0.4
# 32                                     80              0.7
# 33                                     79              1.1
# 34                                     86              0.3
# 35                                     59              1.0
# 36                                     78              0.2
# 37                                     78              6.0
#
#       Employees working very long hours  \
# 0                                  12.5
# 1                                   5.3
# 2                                   4.3
# 3                                   3.3
# 4                                   7.7
# 5                                  23.7
# 6                                  22.0
# 7                                   4.5
# 8                                   1.1
# 9                                   2.2
# 10                                  3.6
# 11                                  7.7
# 12                                  3.9
# 13                                  4.5
# 14                                  1.5
# 15                                 11.7
# 16                                  4.7
# 17                                 14.1
# 18                                  3.3
# 19                                  NaN
# 20                                  NaN
# 21                                  1.6
# 22                                  1.0
# 23                                  2.8
# 24                                 27.0
# 25                                  0.3
# 26                                 14.0
# 27                                  1.4
# 28                                  4.2
# 29                                  5.6
# 30                                  4.2
# 31                                  5.6
# 32                                  2.5
# 33                                  0.9
# 34                                  0.4
# 35                                 25.0
# 36                                 10.8
# 37                                 10.4
#
#       Time devoted to leisure and personal care    Life satisfaction
# 0                                         14.36                  7.1
# 1                                         14.51                  7.2
# 2                                         15.52                  6.8
# 3                                         14.57                  7.0
# 4                                           NaN                  6.2
# 5                                           NaN                  5.7
# 6                                           NaN                  6.3
# 7                                           NaN                  6.9
# 8                                           NaN                  7.5
# 9                                         14.98                  6.5
# 10                                        15.17                  7.9
# 11                                        16.20                  6.7
# 12                                        15.62                  7.3
# 13                                        15.03                  5.8
# 14                                        15.08                  6.0
# 15                                          NaN                  7.6
# 16                                        14.54                  7.0
# 17                                          NaN                  7.2
# 18                                        16.47                  6.5
# 19                                        14.10                  6.1
# 20                                        14.83                  5.8
# 21                                          NaN                  6.2
# 22                                          NaN                  6.4
# 23                                          NaN                  7.4
# 24                                          NaN                  6.0
# 25                                        15.45                  7.5
# 26                                        14.87                  7.3
# 27                                        15.67                  7.3
# 28                                        14.68                  6.1
# 29                                          NaN                  5.8
# 30                                          NaN                  6.5
# 31                                          NaN                  6.5
# 32                                        15.75                  6.5
# 33                                          NaN                  7.3
# 34                                          NaN                  7.5
# 35                                        14.61                  4.9
# 36                                        14.94                  6.8
# 37                                        14.57                  7.0
#
# [38 rows x 26 columns]

# %%
# showing type of data  set in dataframe
data_set.dtypes
# Out:
# Country                                                 object
# GDP per capita (USD)                                     int64
#   Dwellings without basic facilities                   float64
#   Housing expenditure                                  float64
#   Rooms per person                                     float64
#   Household net adjusted disposable income             float64
#   Household net wealth                                 float64
#   Labour market insecurity                             float64
#   Employment rate                                        int64
#   Long-term unemployment rate                          float64
#   Personal earnings                                    float64
#   Quality of support network                             int64
#   Educational attainment                               float64
#   Student skills                                       float64
#   Years in education                                   float64
#   Air pollution                                        float64
#   Water quality                                          int64
#   Stakeholder engagement for developing regulations    float64
#   Voter turnout                                          int64
#   Life expectancy                                      float64
#   Self-reported health                                   int64
#   Feeling safe walking alone at night                    int64
#   Homicide rate                                        float64
#   Employees working very long hours                    float64
#   Time devoted to leisure and personal care            float64
#   Life satisfaction                                    float64
# dtype: object

# %%
data_set.describe()
# Out:
#        GDP per capita (USD)    Dwellings without basic facilities  \
# count             38.000000                             35.000000
# mean           48139.184211                              3.051429
# std            28940.558500                              5.373977
# min             7327.000000                              0.000000
# 25%            26553.000000                              0.200000
# 50%            43469.500000                              0.500000
# 75%            59051.000000                              3.000000
# max           131384.000000                             25.900000
#
#          Housing expenditure    Rooms per person  \
# count              35.000000           37.000000
# mean               20.494286            1.675676
# std                 2.502580            0.413928
# min                14.700000            1.000000
# 25%                18.650000            1.400000
# 50%                20.600000            1.700000
# 75%                21.800000            1.900000
# max                27.400000            2.600000
#
#          Household net adjusted disposable income    Household net wealth  \
# count                                   33.000000               29.000000
# mean                                 30490.151515           323959.620690
# std                                   8184.496163           185528.628032
# min                                  16269.000000            79245.000000
# 25%                                  24590.000000           188627.000000
# 50%                                  29488.000000           294735.000000
# 75%                                  34984.000000           370341.000000
# max                                  51147.000000           941162.000000
#
#          Labour market insecurity    Employment rate  \
# count                   34.000000          38.000000
# mean                     5.182353          68.657895
# std                      4.300280           7.591874
# min                      1.000000          48.000000
# 25%                      2.625000          65.250000
# 50%                      3.900000          70.000000
# 75%                      5.775000          74.000000
# max                     21.700000          80.000000
#
#          Long-term unemployment rate    Personal earnings  ...  \
# count                      37.000000            35.000000  ...
# mean                        1.737838         43783.571429  ...
# std                         1.918094         13953.095782  ...
# min                         0.000000         16230.000000  ...
# 25%                         0.800000         31265.500000  ...
# 50%                         1.200000         45269.000000  ...
# 75%                         2.200000         54766.500000  ...
# max                        10.800000         69392.000000  ...
#
#          Water quality    Stakeholder engagement for developing regulations  \
# count        38.000000                                          38.000000
# mean         84.526316                                           2.150000
# std           8.949519                                           0.580191
# min          62.000000                                           1.200000
# 25%          80.250000                                           1.725000
# 50%          85.000000                                           2.150000
# 75%          91.000000                                           2.575000
# max          98.000000                                           3.200000
#
#          Voter turnout    Life expectancy    Self-reported health  \
# count        38.000000          38.000000               38.000000
# mean         69.105263          80.984211               68.605263
# std          12.513321           2.571836               13.120109
# min          45.000000          75.100000               34.000000
# 25%          62.250000          79.000000               62.750000
# 50%          68.000000          81.900000               71.500000
# 75%          77.750000          82.900000               75.750000
# max          92.000000          84.400000               89.000000
#
#          Feeling safe walking alone at night    Homicide rate  \
# count                              38.000000        38.000000
# mean                               73.842105         2.563158
# std                                12.979248         5.661316
# min                                41.000000         0.200000
# 25%                                69.500000         0.500000
# 50%                                77.000000         0.800000
# 75%                                82.750000         1.275000
# max                                93.000000        26.800000
#
#          Employees working very long hours  \
# count                            36.000000
# mean                              7.202778
# std                               7.269171
# min                               0.300000
# 25%                               2.425000
# 50%                               4.400000
# 75%                              10.500000
# max                              27.000000
#
#          Time devoted to leisure and personal care    Life satisfaction
# count                                    22.000000            38.000000
# mean                                     15.069091             6.686842
# std                                       0.607343             0.665835
# min                                      14.100000             4.900000
# 25%                                      14.580000             6.200000
# 50%                                      14.960000             6.750000
# 75%                                      15.502500             7.275000
# max                                      16.470000             7.900000
#
# [8 rows x 25 columns]

# %%
data_set.shape
# Out:
# (38, 26)

# %%
# checking for duplicate value
data_set.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# dtype: bool

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 26 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Country                                              38 non-null     object
#  1   GDP per capita (USD)                                 38 non-null     int64
#  2     Dwellings without basic facilities                 35 non-null     float64
#  3     Housing expenditure                                35 non-null     float64
#  4     Rooms per person                                   37 non-null     float64
#  5     Household net adjusted disposable income           33 non-null     float64
#  6     Household net wealth                               29 non-null     float64
#  7     Labour market insecurity                           34 non-null     float64
#  8     Employment rate                                    38 non-null     int64
#  9     Long-term unemployment rate                        37 non-null     float64
#  10    Personal earnings                                  35 non-null     float64
#  11    Quality of support network                         38 non-null     int64
#  12    Educational attainment                             37 non-null     float64
#  13    Student skills                                     37 non-null     float64
#  14    Years in education                                 37 non-null     float64
#  15    Air pollution                                      38 non-null     float64
#  16    Water quality                                      38 non-null     int64
#  17    Stakeholder engagement for developing regulations  38 non-null     float64
#  18    Voter turnout                                      38 non-null     int64
#  19    Life expectancy                                    38 non-null     float64
#  20    Self-reported health                               38 non-null     int64
#  21    Feeling safe walking alone at night                38 non-null     int64
#  22    Homicide rate                                      38 non-null     float64
#  23    Employees working very long hours                  36 non-null     float64
#  24    Time devoted to leisure and personal care          22 non-null     float64
#  25    Life satisfaction                                  38 non-null     float64
# dtypes: float64(18), int64(7), object(1)
# memory usage: 7.8+ KB

# %%
import math

# Get the number of numerical columns
num_features = data_set.select_dtypes(include=["number"]).shape[1]

# Determine a suitable grid layout
rows = math.ceil(num_features / 3)  # Adjust rows dynamically
cols = min(3, num_features)  # Limit to 3 columns for readability

# Plot histograms
data_set.hist(figsize=(15, 5 * rows), bins=30, color="skyblue", alpha=0.7, layout=(rows, cols))
plt.suptitle("Distributions of Features", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Correlation matrix (heatmap for numerical features)
plt.figure(figsize=(12, 10))
# Select only numerical features from the DataFrame 'dt'
numerical_features = dt.select_dtypes(include=np.number)
sns.heatmap(numerical_features.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='GDP per capita (USD)', y='  Life satisfaction', data=dt)  # Add leading spaces to '  Life satisfaction'
plt.title('Relationship between GDP per Capita and Life Satisfaction')
plt.xlabel('GDP per capita (USD)')
plt.ylabel('Life satisfaction')
plt.show()

# %%
# Example: Create a box plot for 'GDP per capita (USD)'
plt.figure(figsize=(8, 6))
sns.boxplot(x=dt['GDP per capita (USD)'])
plt.title('Boxplot of GDP per capita (USD)')
plt.show()

# Example: Create a box plot for 'Life satisfaction'
plt.figure(figsize=(8, 6))
sns.boxplot(x=dt['  Life satisfaction'])
plt.title('Boxplot of Life satisfaction')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=data_set, palette="pastel")
plt.title("Boxplots of Numerical Features")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Step 1: Splitting the Dataset

# %%
# Define features and target
X = data_set.drop(columns=['  Life satisfaction'])  # Drop the target column
Y = data_set['  Life satisfaction']  # Set the target variable

# Split the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %% [markdown]
# Step 2: Building a Primary Model

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load dataset
data = pd.read_csv("/content/drive/MyDrive/Assesment Ai/better-life-index-2024.csv")  # Ensure correct path

# Automatically determine target column (assuming last column is target)
target_column = data.columns[-1]  # Change if needed
X = data.drop(columns=[target_column])  # Features
Y = data[target_column]  # Target

# Handle categorical features if present
for col in X.select_dtypes(include=['object']).columns:
    X[col] = LabelEncoder().fit_transform(X[col])

# Drop rows with missing values
X = X.dropna()
Y = Y.loc[X.index]  # Ensure alignment

# Split dataset
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Initialize models
linear_model = LinearRegression()
tree_model = DecisionTreeRegressor(random_state=42)

# Train models
linear_model.fit(X_train, Y_train)
tree_model.fit(X_train, Y_train)

# Make predictions
Y_pred_linear = linear_model.predict(X_test)
Y_pred_tree = tree_model.predict(X_test)

# Evaluate models
mse_linear = mean_squared_error(Y_test, Y_pred_linear)
r2_linear = r2_score(Y_test, Y_pred_linear)

mse_tree = mean_squared_error(Y_test, Y_pred_tree)
r2_tree = r2_score(Y_test, Y_pred_tree)

# Print results
print(f"Linear Regression - MSE: {mse_linear:.4f}, R²: {r2_linear:.4f}")
print(f"Decision Tree - MSE: {mse_tree:.4f}, R²: {r2_tree:.4f}")
# Out:
# Linear Regression - MSE: 0.3855, R²: -9.4540
# Decision Tree - MSE: 0.1650, R²: -3.4746

# %% [markdown]
# Step 3: Building a Model from Scratch (Linear Regression Only)

# %%
import numpy as np

# Feature Scaling (Standardization)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sc_X_train = scaler.fit_transform(X_train)
sc_X_test = scaler.transform(X_test)

# Initialize parameters
def initialize_params(d):
    b = 0  # Bias
    w = np.zeros(d)  # Weights
    return b, w

# Linear function
def linear_function(b, w, X):
    return np.dot(X, w) + b

# Cost function (MSE)
def cost_function(Y_true, Y_pred):
    m = len(Y_true)
    return np.sum((Y_true - Y_pred) ** 2) / (2 * m)

# Gradient descent update
def update_parameters(Y_true, Y_pred, X, b, w, alpha):
    m = len(Y_true)
    dw = -np.dot(X.T, (Y_true - Y_pred)) / m
    db = -np.mean(Y_true - Y_pred)
    w -= alpha * dw
    b -= alpha * db
    return b, w

# Training function
def train_linear_regression(X_train, Y_train, n_iter=5000, alpha=0.01):
    b, w = initialize_params(X_train.shape[1])
    cost_history = []

    for i in range(n_iter):
        Y_hat = linear_function(b, w, X_train)
        cost_now = cost_function(Y_train, Y_hat)
        b, w = update_parameters(Y_train, Y_hat, X_train, b, w, alpha)
        cost_history.append(cost_now)

    return b, w, cost_history

# Train from-scratch model
b, w, cost_history = train_linear_regression(sc_X_train, Y_train, n_iter=5000, alpha=0.01)

# Predictions on test set
Y_test_pred_scratch = linear_function(b, w, sc_X_test)

# Evaluation
test_mse_scratch = mean_squared_error(Y_test, Y_test_pred_scratch)
test_r2_scratch = r2_score(Y_test, Y_test_pred_scratch)

print(f"From Scratch Model - MSE: {test_mse_scratch:.4f}, R²: {test_r2_scratch:.4f}")
# Out:
# From Scratch Model - MSE: 0.1532, R²: -3.1548

# %% [markdown]
# Step 4: Hyperparameter Optimization with Cross-Validation

# %% [markdown]
# 1. Ridge Regression (L2 Regularization) - Hyperparameter Tuning

# %%
# Define parameter grid for Ridge (L2)
param_grid_ridge = {'alpha': [0.01, 0.1, 1, 10, 100]}

# Apply GridSearchCV
ridge_grid = GridSearchCV(Ridge(), param_grid_ridge, cv=5, scoring='neg_mean_squared_error')
ridge_grid.fit(X_train, Y_train)

# Best hyperparameter
best_ridge_alpha = ridge_grid.best_params_['alpha']
print(f"Best Ridge alpha: {best_ridge_alpha}")

# Train Ridge model with best alpha
ridge_best = Ridge(alpha=best_ridge_alpha)
ridge_best.fit(X_train, Y_train)

# Predict & Evaluate Ridge
ridge_preds = ridge_best.predict(X_test)
ridge_mse = mean_squared_error(Y_test, ridge_preds)
print(f"Ridge Test MSE: {ridge_mse}")
# Out:
# Best Ridge alpha: 100
# Ridge Test MSE: 0.21355630215730198

# %% [markdown]
# 2. Decision Tree Regression - Hyperparameter Tuning

# %%
# Define hyperparameter grid for Decision Tree
param_grid_tree = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Apply GridSearchCV
tree_grid = GridSearchCV(DecisionTreeRegressor(random_state=42), param_grid_tree, cv=5, scoring='neg_mean_squared_error')
tree_grid.fit(X_train, Y_train)

# Best hyperparameters
best_tree_params = tree_grid.best_params_
print(f"best tree parameters: {best_tree_params}")

# Train Decision Tree with best parameters
tree_best = DecisionTreeRegressor(**best_tree_params, random_state=42)
tree_best.fit(X_train, Y_train)

# Predict & Evaluate Decision Tree
tree_preds = tree_best.predict(X_test)
tree_mse = mean_squared_error(Y_test, tree_preds)
print(f"Decision Tree Test MSE: {tree_mse}")
# Out:
# best tree parameters: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Decision Tree Test MSE: 0.2055612244897951

# %% [markdown]
# Step 6 :  Summary of Best Hyperparameters & Performance

# %%
# Define parameter grid for Lasso (L1)
param_grid_lasso = {'alpha': [0.01, 0.1, 1, 10, 100]}

# Apply GridSearchCV
lasso_grid = GridSearchCV(Lasso(), param_grid_lasso, cv=5, scoring='neg_mean_squared_error')
lasso_grid.fit(X_train, Y_train)

# Best hyperparameter
best_lasso_alpha = lasso_grid.best_params_['alpha']
print(f"Best Lasso alpha: {best_lasso_alpha}")

# Train Lasso model with best alpha
lasso_best = Lasso(alpha=best_lasso_alpha)
lasso_best.fit(X_train, Y_train)

# Predict & Evaluate Lasso
lasso_preds = lasso_best.predict(X_test)
lasso_mse = mean_squared_error(Y_test, lasso_preds)
print(f"Lasso Test MSE: {lasso_mse}")
# Out:
# Best Lasso alpha: 100
# Lasso Test MSE: 0.07177708155326884
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.618e-02, tolerance: 2.876e-04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.509e-02, tolerance: 4.500e-04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.658e-03, tolerance: 2.416e-04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e-02, tolerance: 4.289e-04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.098e-02, tolerance: 4.289e-04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.199e-01, tolerance: 2.876e-04
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Step7: Feature Selection

# %%
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest, f_regression

# Initialize the models for RFE
linear_model = LinearRegression()
tree_model = DecisionTreeRegressor(random_state=42)

# Initialize RFE for Linear Regression
rfe_linear = RFE(estimator=linear_model, n_features_to_select=5)
X_train_rfe_linear = rfe_linear.fit_transform(X_train, Y_train)
X_test_rfe_linear = rfe_linear.transform(X_test)

# Initialize RFE for Decision Tree
rfe_tree = RFE(estimator=tree_model, n_features_to_select=5)
X_train_rfe_tree = rfe_tree.fit_transform(X_train, Y_train)
X_test_rfe_tree = rfe_tree.transform(X_test)

# Get rankings of features
linear_ranking = rfe_linear.ranking_
tree_ranking = rfe_tree.ranking_

# Show feature rankings
print("Linear Model Feature Rankings:")
for feature, rank in zip(X.columns, linear_ranking):
    print(f"{feature}: Rank {rank}")

print("\nDecision Tree Feature Rankings:")
for feature, rank in zip(X.columns, tree_ranking):
    print(f"{feature}: Rank {rank}")
# Out:
# Linear Model Feature Rankings:
# Country: Rank 10
# GDP per capita (USD): Rank 21
#   Dwellings without basic facilities: Rank 1
#   Housing expenditure: Rank 2
#   Rooms per person: Rank 15
#   Household net adjusted disposable income: Rank 19
#   Household net wealth: Rank 20
#   Labour market insecurity: Rank 1
#   Employment rate: Rank 3
#   Long-term unemployment rate: Rank 9
#   Personal earnings: Rank 18
#   Quality of support network: Rank 16
#   Educational attainment: Rank 4
#   Student skills: Rank 17
#   Years in education: Rank 1
#   Air pollution: Rank 1
#   Water quality: Rank 6
#   Stakeholder engagement for developing regulations: Rank 8
#   Voter turnout: Rank 7
#   Life expectancy: Rank 12
#   Self-reported health: Rank 13
#   Feeling safe walking alone at night: Rank 11
#   Homicide rate: Rank 1
#   Employees working very long hours: Rank 5
#   Time devoted to leisure and personal care: Rank 14
#
# Decision Tree Feature Rankings:
# Country: Rank 21
# GDP per capita (USD): Rank 20
#   Dwellings without basic facilities: Rank 19
#   Housing expenditure: Rank 18
#   Rooms per person: Rank 17
#   Household net adjusted disposable income: Rank 1
#   Household net wealth: Rank 1
#   Labour market insecurity: Rank 12
#   Employment rate: Rank 11
#   Long-term unemployment rate: Rank 10
#   Personal earnings: Rank 8
#   Quality of support network: Rank 9
#   Educational attainment: Rank 7
#   Student skills: Rank 14
#   Years in education: Rank 16
#   Air pollution: Rank 15
#   Water quality: Rank 13
#   Stakeholder engagement for developing regulations: Rank 5
#   Voter turnout: Rank 6
#   Life expectancy: Rank 4
#   Self-reported health: Rank 3
#   Feeling safe walking alone at night: Rank 2
#   Homicide rate: Rank 1
#   Employees working very long hours: Rank 1
#   Time devoted to leisure and personal care: Rank 1

# %% [markdown]
# Step8 : Final model

# %%
# Rebuild the Linear Regression model with selected features
final_linear_model = LinearRegression()
final_linear_model.fit(X_train_rfe_linear, Y_train)

# Predict and evaluate
Y_pred_linear_final = final_linear_model.predict(X_test_rfe_linear)
final_mse_linear = mean_squared_error(Y_test, Y_pred_linear_final)
final_r2_linear = r2_score(Y_test, Y_pred_linear_final)

# Rebuild the Decision Tree model with selected features
final_tree_model = DecisionTreeRegressor(**best_tree_params, random_state=42)
final_tree_model.fit(X_train_rfe_tree, Y_train)

# Predict and evaluate
Y_pred_tree_final = final_tree_model.predict(X_test_rfe_tree)
final_mse_tree = mean_squared_error(Y_test, Y_pred_tree_final)
final_r2_tree = r2_score(Y_test, Y_pred_tree_final)

# Print the final evaluation metrics
print("\nFinal Model Evaluation:")
print(f"Linear Regression - MSE: {final_mse_linear:.4f}, R²: {final_r2_linear:.4f}")
print(f"Decision Tree - MSE: {final_mse_tree:.4f}, R²: {final_r2_tree:.4f}")
# Out:
# Final Model Evaluation:
# Linear Regression - MSE: 0.0954, R²: -1.5870
# Decision Tree - MSE: 0.2056, R²: -4.5745
